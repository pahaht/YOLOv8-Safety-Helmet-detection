# %% [markdown]
# # Safety Helmet detection

# %%
from ultralytics import YOLO
 
  Load the model.
 model = YOLO('yolov8n.pt')
 
  Training.
  results = model.train(
    data='path to dataset\data.yaml',    
    imgsz=640,
    epochs=100,
   batch=8,
 )

# %% [markdown]
# ## Loading Safety Helmet pre-trained model

# %%
from ultralytics import YOLO
model = YOLO('weight_path\')

# %% [markdown]
# ## Prediction(1)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 480x640 3 helmets, 712.1ms
# Speed: 18.9ms preprocess, 712.1ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict8

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict8/sh2.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=565x403>

# %% [markdown]
# ## Prediction(2)

# %%
from PIL import Image
# from PIL
im1 = Image.open('input image_path')
results = model.predict(source=im1, save=True)
# Out:
# 0: 512x640 4 helmets, 2 vests, 1116.0ms
# Speed: 17.0ms preprocess, 1116.0ms inference, 6.0ms postprocess per image at shape (1, 3, 512, 640)
# Results saved to runs\detect\predict8

# %% [markdown]
# ## Detection

# %%
display(Image.open('runs/detect/predict8/sh3.jpg'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=596x469>
